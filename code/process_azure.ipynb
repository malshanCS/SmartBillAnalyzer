# %%
from datetime import datetime
import csv
import pandas as pd
import os

# %%
csv_file = '../files/isp_azure.csv'
if not os.path.isfile(csv_file):
    # If the file doesn't exist, create it with a header
    df = pd.DataFrame(columns=['image_path', 'ISP', 'date', 'amount'])
    df.to_csv(csv_file, index=False)
else:
    # If the file exists, append the data to the DataFrame
    df = pd.read_csv(csv_file)

# %%
def convert_date(date_str):
    try:
        # Attempt to parse the date in "month/day/year" format
        date_obj = datetime.strptime(date_str, "%d/%m/%Y")
        # Convert it to "year-month-day" format
        return date_obj.strftime("%Y-%m-%d")
    except ValueError:
        # If the date is already in "year-month-day" format or is not a valid date, return it as is
        return date_str

# %%
folder_path = '../Data/All_bills'

# Get a list of all files in the folder
file_list = os.listdir(folder_path)


# Filter the list to keep only image files (you can add more extensions if needed)
image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp']
image_files = [f for f in file_list if any(f.lower().endswith(ext) for ext in image_extensions)]

# %%
# !pip install azure-ai-formrecognizer==3.3.0
# Out:
# Collecting azure-ai-formrecognizer==3.3.0
#   Obtaining dependency information for azure-ai-formrecognizer==3.3.0 from https://files.pythonhosted.org/packages/ec/d6/255f4afed1e4d0e2aaf1b988d4c5ae453b65d9b92a3370634d7523804fd7/azure_ai_formrecognizer-3.3.0-py3-none-any.whl.metadata
#   Downloading azure_ai_formrecognizer-3.3.0-py3-none-any.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.8 kB 222.6 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.8 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 61.8/61.8 kB 412.5 kB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.23.0 (from azure-ai-formrecognizer==3.3.0)
#   Obtaining dependency information for azure-core<2.0.0,>=1.23.0 from https://files.pythonhosted.org/packages/9c/f8/1cf23a75cb8c2755c539ac967f3a7f607887c4979d073808134803720f0f/azure_core-1.29.5-py3-none-any.whl.metadata
#   Downloading azure_core-1.29.5-py3-none-any.whl.metadata (36 kB)
# Collecting msrest>=0.6.21 (from azure-ai-formrecognizer==3.3.0)
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ---------------------------------------- 0.0/85.4 kB ? eta -:--:--
#      ---------------------------------------- 85.4/85.4 kB 2.4 MB/s eta 0:00:00
# Collecting azure-common~=1.1 (from azure-ai-formrecognizer==3.3.0)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from azure-ai-formrecognizer==3.3.0) (4.8.0)
# Requirement already satisfied: requests>=2.18.4 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer==3.3.0) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer==3.3.0) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.3.0) (2023.7.22)
# Collecting isodate>=0.6.0 (from msrest>=0.6.21->azure-ai-formrecognizer==3.3.0)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#      ---------------------------------------- 41.7/41.7 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.3.0) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer==3.3.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer==3.3.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer==3.3.0) (1.26.16)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\anaconda3\envs\dl\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer==3.3.0) (3.2.2)
# Downloading azure_ai_formrecognizer-3.3.0-py3-none-any.whl (297 kB)
#    ---------------------------------------- 0.0/297.8 kB ? eta -:--:--
#    -------------------------- ------------- 194.6/297.8 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 297.8/297.8 kB 4.6 MB/s eta 0:00:00
# Downloading azure_core-1.29.5-py3-none-any.whl (192 kB)
#    ---------------------------------------- 0.0/192.4 kB ? eta -:--:--
#    --------------------------------------- 192.4/192.4 kB 11.4 MB/s eta 0:00:00
# Installing collected packages: azure-common, isodate, azure-core, msrest, azure-ai-formrecognizer
# Successfully installed azure-ai-formrecognizer-3.3.0 azure-common-1.1.28 azure-core-1.29.5 isodate-0.6.1 msrest-0.7.1

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""

endpoint = "https://thilakna-doc-intelligence-instance.cognitiveservices.azure.com/"
key = "29579bf5af1f4559bb8228d643e79d7b"
model_id = "ISP-M1"

# Initialize the DocumentAnalysisClient
document_analysis_client = DocumentAnalysisClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)

# %%
# Loop through the image files and open each one
for image_file in image_files:
    # Construct the full path to the image file
    image_path = os.path.join(folder_path, image_file)
    # if image_path in df['image_path'].tolist():
    #     print(f"Skipping image {image_file} as it's already in the DataFrame.")
    #     continue


    try:
      # Analyze the document using the custom model
      with open(image_path, "rb") as document:
        poller = document_analysis_client.begin_analyze_document(model_id, document)
      result = poller.result()
            # Process the analysis results as before
      for idx, document in enumerate(result.documents):
          # print("--------Analyzing document #{}--------".format(idx + 1))
          # print("Document has type {}".format(document.doc_type))
          # print("Document has confidence {}".format(document.confidence))
          # print("Document was analyzed by model with ID {}".format(result.model_id))

          data = []
          for name, field in document.fields.items():
              field_value = field.value if field.value else field.content
              data.append(field_value)

          # Append the data to the existing CSV file
          data_dict = {
              "image_path": [image_path],
              "date":[data[2]],  # Adjust the index to match the data
              "amount": [data[0]],  # Adjust the index to match the data
              "isp": [data[1]],  # Adjust the index to match the data
          }
          df = pd.DataFrame(data_dict)
          df.to_csv('../files/isp_azure.csv', mode='a', header=False, index=False)
    except Exception as e:
      print(e)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_old = pd.read_csv('../files/isp_data_2.csv')
df_old
# Out:
#                                           oimage_path     ISP        date  \
# 0   ../Data/batch_process\upload_image_00467868600...     SLT  2022-11-02
# 1        ../Data/batch_process\upload_image_1.png.png  Dialog  2021-12-48
# 2       ../Data/batch_process\upload_image_10.png.png  Dialog  2023-01-04
# 3       ../Data/batch_process\upload_image_11.png.png  Dialog  2023-01-26
# 4       ../Data/batch_process\upload_image_12.png.png  Dialog  2023-02-27
# 5        ../Data/batch_process\upload_image_2.png.png  Dialog  2022-03-25
# 6        ../Data/batch_process\upload_image_3.png.png  Dialog  2022-05-31
# 7        ../Data/batch_process\upload_image_4.png.png  Dialog  2022-07-04
# 8        ../Data/batch_process\upload_image_5.png.png  Dialog         NaN
# 9        ../Data/batch_process\upload_image_6.png.png  Dialog  2022-08-07
# 10       ../Data/batch_process\upload_image_7.png.png  Dialog  2022-08-28
# 11       ../Data/batch_process\upload_image_8.png.png  Dialog  2022-11-04
# 12       ../Data/batch_process\upload_image_9.png.png  Dialog  2022-42-27
# 13  ../Data/batch_process\upload_image_document (1...     SLT  2022-10-02
# 14  ../Data/batch_process\upload_image_document (7...     SLT  2022-12-02
# 15  ../Data/batch_process\upload_image_image1-1.pn...     SLT  2023-08-02
# 16  ../Data/batch_process\upload_image_image2-1.pn...     SLT  2023-07-02
# 17  ../Data/batch_process\upload_image_image3-1.pn...     SLT  2023-06-02
# 18  ../Data/batch_process\upload_image_image4-1.pn...     SLT  2023-05-02
# 19  ../Data/batch_process\upload_image_image5-1.pn...     SLT  2023-04-02
# 20  ../Data/batch_process\upload_image_image6-1.pn...     SLT  2023-02-02
# 21  ../Data/batch_process\upload_image_image7-1.pn...     SLT  2022-12-02
# 22  ../Data/batch_process\upload_image_image8-1.pn...     SLT  2022-11-02
# 23  ../Data/batch_process\upload_image_SLT eBill-0...     SLT  2022-10-02
# 24  ../Data/batch_process\upload_image_SLT eBill-0...     SLT  2022-12-02
# 25  ../Data/batch_process\upload_image_SLT eBill-0...     SLT  2023-01-02
# 26  ../Data/batch_process\upload_image_SLT eBill-0...     SLT  2023-02-02
# 27  ../Data/batch_process\upload_image_SLT eBill-0...     SLT  2023-07-02
#
#      amount
# 0   4044.86
# 1   2890.44
# 2   2800.00
# 3   4200.00
# 4   4000.00
# 5    500.00
# 6    200.00
# 7   2228.56
# 8    200.00
# 9    200.00
# 10  4387.28
# 11   700.00
# 12  4200.00
# 13  3585.79
# 14  2010.09
# 15  7317.28
# 16  7551.97
# 17  7828.77
# 18  7786.65
# 19  7317.28
# 20  7317.28
# 21  7618.15
# 22  9531.73
# 23  8920.42
# 24  8964.63
# 25  8392.96
# 26  5185.65
# 27  7213.54

# %%
df_new = pd.read_csv('../files/isp_azure.csv')
# df_new

# %%
df_new.loc[df_new["ISP"].str.contains("MOBITEL"), "ISP"] = "SLT"

# df_new

# %%
from dateutil import parser

df_new['date'] = df_new['date'].apply(lambda x: parser.parse(x).strftime('%d-%m-%Y'))
df_new
# Out:
#                                            image_path     ISP        date  \
# 0         ../Data/All_bills\0046786860019XImage-1.png     SLT  11-02-2022
# 1                             ../Data/All_bills\1.png  Dialog  16-12-2021
# 2                            ../Data/All_bills\10.png  Dialog  04-01-2023
# 3                            ../Data/All_bills\11.png  Dialog  26-01-2023
# 4                            ../Data/All_bills\12.png  Dialog  27-02-2023
# 5                             ../Data/All_bills\2.png  Dialog  23-03-2022
# 6                             ../Data/All_bills\3.png  Dialog  31-05-2022
# 7                             ../Data/All_bills\4.png  Dialog  04-07-2022
# 8                             ../Data/All_bills\5.png  Dialog  15-07-2022
# 9                             ../Data/All_bills\6.png  Dialog  07-08-2022
# 10                            ../Data/All_bills\7.png  Dialog  28-08-2022
# 11                            ../Data/All_bills\8.png  Dialog  04-11-2022
# 12                            ../Data/All_bills\9.png  Dialog  27-12-2022
# 13              ../Data/All_bills\document (10)-1.png     SLT  10-02-2022
# 14               ../Data/All_bills\document (7)-1.png     SLT  12-02-2022
# 15                     ../Data/All_bills\image1-1.png     SLT  08-02-2023
# 16                     ../Data/All_bills\image2-1.png     SLT  07-02-2023
# 17                     ../Data/All_bills\image3-1.png     SLT  06-02-2023
# 18                     ../Data/All_bills\image4-1.png     SLT  05-02-2023
# 19                     ../Data/All_bills\image5-1.png     SLT  04-02-2023
# 20                     ../Data/All_bills\image6-1.png     SLT  02-02-2023
# 21                     ../Data/All_bills\image7-1.png     SLT  12-02-2022
# 22                     ../Data/All_bills\image8-1.png     SLT  11-02-2022
# 23  ../Data/All_bills\SLT eBill-002311885X1789Imag...     SLT  10-02-2022
# 24  ../Data/All_bills\SLT eBill-002311885X1790Imag...     SLT  11-02-2022
# 25  ../Data/All_bills\SLT eBill-002311885X1800Imag...     SLT  12-02-2022
# 26  ../Data/All_bills\SLT eBill-002311885X1812Imag...     SLT  01-02-2023
# 27  ../Data/All_bills\SLT eBill-002311885X1824Imag...     SLT  02-02-2023
# 28  ../Data/All_bills\SLT eBill-002311885X1873Imag...     SLT  07-02-2023
#
#       amount
# 0   4,044.86
# 1   2,890.44
# 2   2,800.00
# 3   1,200.00
# 4   1,000.00
# 5     500.00
# 6     800.00
# 7   2,226.56
# 8     800.00
# 9     800.00
# 10  1,387.23
# 11    700.00
# 12  1,200.00
# 13  3,585.79
# 14  2,010.09
# 15  7,317.28
# 16  7,551.97
# 17  7,828.77
# 18  7,786.65
# 19  7,317.28
# 20  7,317.28
# 21  7,618.15
# 22  9,531.73
# 23  8,920.42
# 24  7,185.20
# 25  8,964.63
# 26  8,392.96
# 27  5,185.65
# 28  7,213.54
